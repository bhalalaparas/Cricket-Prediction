# %%
import numpy as np
import pandas as pd

# %%
matches = pd.read_csv(r'C:\Users\paras\Desktop\Project\ipl\match_data.csv')

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 24 columns):
# id                  746 non-null int64
# season              746 non-null int64
# city                733 non-null object
# date                746 non-null object
# team1               746 non-null object
# team2               746 non-null object
# toss_winner         746 non-null object
# toss_decision       746 non-null object
# winner              734 non-null object
# eliminator          8 non-null object
# dl_applied          19 non-null object
# win_by_runs         336 non-null float64
# win_by_wickets      398 non-null float64
# result              12 non-null object
# overs               746 non-null int64
# player_of_match     742 non-null object
# venue               746 non-null object
# umpire1             745 non-null object
# umpire2             745 non-null object
# umpire3             2 non-null object
# first_bat_team      746 non-null object
# first_bowl_team     746 non-null object
# first_bat_score     746 non-null float64
# second_bat_score    744 non-null float64
# dtypes: float64(4), int64(3), object(17)
# memory usage: 140.0+ KB

# %%
matches[pd.isnull(matches['winner'])]
matches['winner'].fillna('Draw', inplace=True)

# %%
matches.replace(['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore','Deccan Chargers','Chennai Super Kings',
                 'Rajasthan Royals','Delhi Daredevils','Delhi Capitals','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants','Rising Pune Supergiant','Kochi Tuskers Kerala','Pune Warriors']
                ,['MI','KKR','RCB','DC','CSK','RR','DD','DD','GL','KXIP','SRH','RPS','RPS','KTK','PW'],inplace=True)

# %%
encode = {'team1': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'team2': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'toss_winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'Draw':14}}

# %%
matches.replace(encode, inplace=True)

# %%
matches[pd.isnull(matches['city'])]
# Out:
#          id  season city        date  team1  team2  toss_winner toss_decision  \
# 55   729303    2014  NaN  2014-04-25      5      1            1           bat
# 78   729311    2014  NaN  2014-04-27     10      5           10           bat
# 83   729299    2014  NaN  2014-04-24      3      2            3         field
# 149  729317    2014  NaN  2014-04-30      1     10            1         field
# 207  729287    2014  NaN  2014-04-19      3      1            3         field
# 230  729295    2014  NaN  2014-04-22      9     10           10         field
# 317  729309    2014  NaN  2014-04-27      7      1            1           bat
# 324  729281    2014  NaN  2014-04-17      7      3            3         field
# 398  729291    2014  NaN  2014-04-20      6      9            9         field
# 507  729297    2014  NaN  2014-04-23      6      5            6         field
# 712  729301    2014  NaN  2014-04-25     10      7           10           bat
# 714  729289    2014  NaN  2014-04-19      2      7            2           bat
# 744  729313    2014  NaN  2014-04-28      9      3            9         field
#
#      winner eliminator  ... overs  player_of_match  \
# 55        5        NaN  ...    20        MM Sharma
# 78        5        NaN  ...    20         DR Smith
# 83        2        NaN  ...    20          CA Lynn
# 149      10        NaN  ...    20          B Kumar
# 207       3        NaN  ...    20         PA Patel
# 230       9        NaN  ...    20       GJ Maxwell
# 317       7        NaN  ...    20          M Vijay
# 324       3        NaN  ...    20        YS Chahal
# 398       9        NaN  ...    20       GJ Maxwell
# 507       5        NaN  ...    20        RA Jadeja
# 712      10        NaN  ...    20         AJ Finch
# 714       7        NaN  ...    20        JP Duminy
# 744       9        NaN  ...    20   Sandeep Sharma
#
#                                    venue          umpire1         umpire2  \
# 55   Dubai International Cricket Stadium        BF Bowden       M Erasmus
# 78               Sharjah Cricket Stadium     AK Chaudhary     VA Kulkarni
# 83               Sharjah Cricket Stadium        Aleem Dar     VA Kulkarni
# 149  Dubai International Cricket Stadium  HDPK Dharmasena       M Erasmus
# 207  Dubai International Cricket Stadium        Aleem Dar    AK Chaudhary
# 230              Sharjah Cricket Stadium        M Erasmus          S Ravi
# 317              Sharjah Cricket Stadium        Aleem Dar     VA Kulkarni
# 324              Sharjah Cricket Stadium        Aleem Dar          S Ravi
# 398              Sharjah Cricket Stadium        BF Bowden       M Erasmus
# 507  Dubai International Cricket Stadium  HDPK Dharmasena  RK Illingworth
# 712  Dubai International Cricket Stadium        M Erasmus          S Ravi
# 714  Dubai International Cricket Stadium        Aleem Dar     VA Kulkarni
# 744  Dubai International Cricket Stadium        BF Bowden          S Ravi
#
#     umpire3 first_bat_team first_bowl_team first_bat_score second_bat_score
# 55      NaN             MI             CSK           141.0            142.0
# 78      NaN            SRH             CSK           145.0            146.0
# 83      NaN            KKR             RCB           150.0            148.0
# 149     NaN            SRH              MI           172.0            157.0
# 207     NaN             MI             RCB           115.0            116.0
# 230     NaN           KXIP             SRH           193.0            121.0
# 317     NaN             MI              DD           125.0            126.0
# 324     NaN             DD             RCB           145.0            146.0
# 398     NaN             RR            KXIP           191.0            193.0
# 507     NaN            CSK              RR           140.0            133.0
# 712     NaN            SRH              DD           184.0            180.0
# 714     NaN            KKR              DD           166.0            167.0
# 744     NaN            RCB            KXIP           124.0            127.0
#
# [13 rows x 24 columns]

# %%
matches['city'].fillna('Dubai',inplace=True)

# %%
matches[pd.isnull(matches['city'])]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, winner, eliminator, dl_applied, win_by_runs, win_by_wickets, result, overs, player_of_match, venue, umpire1, umpire2, umpire3, first_bat_team, first_bowl_team, first_bat_score, second_bat_score]
# Index: []
#
# [0 rows x 24 columns]

# %%
matches.describe()
# Out:
#                  id       season       team1       team2  toss_winner  \
# count  7.460000e+02   746.000000  746.000000  746.000000   746.000000
# mean   7.135520e+05  2013.369973    5.517426    5.498660     5.388740
# std    2.845419e+05     3.326906    3.254377    3.329449     3.221002
# min    3.359820e+05  2008.000000    1.000000    1.000000     1.000000
# 25%    5.012092e+05  2011.000000    3.000000    2.000000     3.000000
# 50%    5.980485e+05  2013.000000    5.000000    5.000000     5.000000
# 75%    9.809845e+05  2016.000000    8.000000    9.000000     7.000000
# max    1.178425e+06  2019.000000   13.000000   13.000000    13.000000
#
#            winner  win_by_runs  win_by_wickets  overs  first_bat_score  \
# count  746.000000   336.000000      398.000000  746.0       746.000000
# mean     5.422252    29.883929        6.251256   20.0       161.356568
# std      3.369024    27.276827        1.821281    0.0        30.537844
# min      1.000000     1.000000        1.000000   20.0        56.000000
# 25%      2.000000    11.000000        5.000000   20.0       142.000000
# 50%      5.000000    22.000000        6.000000   20.0       163.000000
# 75%      8.000000    39.000000        8.000000   20.0       182.000000
# max     14.000000   146.000000       10.000000   20.0       263.000000
#
#        second_bat_score
# count        744.000000
# mean         147.841398
# std           31.153406
# min            2.000000
# 25%          131.000000
# 50%          150.000000
# 75%          169.000000
# max          223.000000

# %%
dicVal = encode['winner']

# %%
dicVal
# Out:
# {'MI': 1,
#  'KKR': 2,
#  'RCB': 3,
#  'DC': 4,
#  'CSK': 5,
#  'RR': 6,
#  'DD': 7,
#  'GL': 8,
#  'KXIP': 9,
#  'SRH': 10,
#  'RPS': 11,
#  'KTK': 12,
#  'PW': 13,
#  'Draw': 14}

# %%
dicVal['MI']
# Out:
# 1

# %%
list(dicVal.keys())[0]
# Out:
# 'MI'

# %%
print(list(dicVal.keys())[list(dicVal.values()).index(1)])
# Out:
# MI

# %%
print([list(dicVal.values()).index(14)])
# Out:
# [13]

# %%
matches = matches[['team1','team2','city','toss_decision','toss_winner','venue','winner']]

# %%
df = pd.DataFrame(matches)
df.describe()
# Out:
#             team1       team2  toss_winner      winner
# count  746.000000  746.000000   746.000000  746.000000
# mean     5.517426    5.498660     5.388740    5.422252
# std      3.254377    3.329449     3.221002    3.369024
# min      1.000000    1.000000     1.000000    1.000000
# 25%      3.000000    2.000000     3.000000    2.000000
# 50%      5.000000    5.000000     5.000000    5.000000
# 75%      8.000000    9.000000     7.000000    8.000000
# max     13.000000   13.000000    13.000000   14.000000

# %%
df
# Out:
#      team1  team2         city toss_decision  toss_winner  \
# 0        3      4       Mumbai           bat            4
# 1        7      2        Delhi           bat            7
# 2        1      2       Mumbai         field            1
# 3       11      3         Pune         field           11
# 4        5      4       Mumbai           bat            5
# ..     ...    ...          ...           ...          ...
# 741     10      1    Hyderabad         field           10
# 742      5      4  East London           bat            5
# 743      3      1    Bangalore         field            1
# 744      9      3        Dubai         field            9
# 745      3      1    Bangalore         field            3
#
#                                          venue  winner
# 0                   Dr DY Patil Sports Academy       3
# 1                             Feroz Shah Kotla       7
# 2                             Wankhede Stadium       1
# 3      Maharashtra Cricket Association Stadium       3
# 4                   Dr DY Patil Sports Academy       5
# ..                                         ...     ...
# 741  Rajiv Gandhi International Stadium, Uppal      10
# 742                               Buffalo Park       5
# 743                      M Chinnaswamy Stadium       1
# 744        Dubai International Cricket Stadium       9
# 745                      M Chinnaswamy Stadium       1
#
# [746 rows x 7 columns]

# %%
temp1 = df['toss_winner'].value_counts(sort=True)

# %%
temp1
# Out:
# 1     95
# 2     91
# 7     89
# 5     87
# 9     80
# 3     80
# 6     79
# 10    46
# 4     43
# 13    20
# 8     15
# 11    13
# 12     8
# Name: toss_winner, dtype: int64

# %%
temp2=df['winner'].value_counts(sort=True)

# %%
#No of toss winners by each team
for idx, val in temp1.iteritems():
   print('{} -> {}'.format(list(dicVal.keys())[list(dicVal.values()).index(idx)],val))
# Out:
# MI -> 95
# KKR -> 91
# DD -> 89
# CSK -> 87
# KXIP -> 80
# RCB -> 80
# RR -> 79
# SRH -> 46
# DC -> 43
# PW -> 20
# GL -> 15
# RPS -> 13
# KTK -> 8

# %%
#No of match winners by each team
for idx, val in temp2.iteritems():
   print('{} -> {}'.format(list(dicVal.keys())[list(dicVal.values()).index(idx)],val))
# Out:
# MI -> 104
# CSK -> 99
# KKR -> 91
# RCB -> 82
# KXIP -> 79
# DD -> 74
# RR -> 73
# SRH -> 57
# DC -> 29
# RPS -> 15
# GL -> 13
# Draw -> 12
# PW -> 12
# KTK -> 6

# %%
df['winner'].hist(bins=40).plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Count of toss wins')
ax1.set_title("toss winners")
temp1.plot(kind='bar')

ax2 = fig.add_subplot(122)
temp2.plot(kind = 'bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('count of matches won')
ax2.set_title("Match winners")
# Out:
# Text(0.5, 1.0, 'Match winners')

# %%
#Checks for null values in the rows
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# team1            0
# team2            0
# city             0
# toss_decision    0
# toss_winner      0
# venue            0
# winner           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['city','toss_decision','venue']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i])
df.dtypes
# Out:
# team1            int64
# team2            int64
# city             int32
# toss_decision    int32
# toss_winner      int64
# venue            int32
# winner           int64
# dtype: object

# %%
df
# Out:
#      team1  team2  city  toss_decision  toss_winner  venue  winner
# 0        3      4    23              0            4      4       3
# 1        7      2    10              0            7      8       7
# 2        1      2    23              1            1     35       1
# 3       11      3    26              1           11     17       3
# 4        5      4    23              0            5      4       5
# ..     ...    ...   ...            ...          ...    ...     ...
# 741     10      1    15              1           10     24      10
# 742      5      4    14              0            5      2       5
# 743      3      1     2              1            1     14       1
# 744      9      3    12              1            9      6       9
# 745      3      1     2              1            3     14       1
#
# [746 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression
#from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
from sklearn.model_selection import train_test_split
def classification_model(model, data, predictors, outcome):
  model.fit(data[predictors],data[outcome])
  predictions = model.predict(data[predictors])
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  #print('Accuracy : %s' % '{0:.3%}'.format(accuracy))
  print("Training Model Accuracy",accuracy*100)  
  training_x, testing_x ,training_y,testing_y = train_test_split(data[predictors],data[outcome],test_size = 0.25, random_state=0)
  '''print(training_x)
  print(testing_x)
  print(training_y)
  print(testing_y)'''
  
  model.fit(testing_x,testing_y)
  predictions_ = model.predict(testing_x)
  accuracy_ = metrics.accuracy_score(predictions_,testing_y)
  print("Testing Model Accuracy",accuracy_*100)
    
  
  #kf = KFold(data.shape[0], n_folds=7)
  #error = []
  #for train, test in kf:
   # train_predictors = (data[predictors].iloc[train,:])
    #train_target = data[outcome].iloc[train]
    #model.fit(train_predictors, train_target)
    #error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
 # print('Cross-Validation Score : %s' % '{0:.3%}'.format(np.mean(error)))"""

  model.fit(data[predictors],data[outcome])
 
    

from sklearn.ensemble import RandomForestRegressor
outcome_var=['winner']
predictor_var = ['team1','team2','toss_winner']
model = LogisticRegression()
classification_model(model, df,predictor_var,outcome_var)
df.head(3)
# Out:
# Training Model Accuracy 24.128686327077748
# Testing Model Accuracy 28.87700534759358
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
#    team1  team2  city  toss_decision  toss_winner  venue  winner
# 0      3      4    23              0            4      4       3
# 1      7      2    10              0            7      8       7
# 2      1      2    23              1            1     35       1

# %%
model = RandomForestClassifier(n_estimators=100)
outcome_var = ['winner']
predictor_var = ['team1', 'team2', 'venue', 'toss_winner','city','toss_decision']
classification_model(model, df,predictor_var,outcome_var)
df.head(7)
# Out:
# C:\Users\paras\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Training Model Accuracy 86.99731903485255
# C:\Users\paras\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Testing Model Accuracy 96.79144385026738
# C:\Users\paras\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#    team1  team2  city  toss_decision  toss_winner  venue  winner
# 0      3      4    23              0            4      4       3
# 1      7      2    10              0            7      8       7
# 2      1      2    23              1            1     35       1
# 3     11      3    26              1           11     17       3
# 4      5      4    23              0            5      4       5
# 5      9      3     7              0            9     23       3
# 6      3      7     2              1            7     14       7

# %%
team1='DD'
team2='KKR'
toss_winner='DD'
input=[dicVal[team1],dicVal[team2],'14',dicVal[toss_winner],'2','1']
input = np.array(input).reshape((1, -1))
output=model.predict(input)
print(output)
print("Possible winner : "+list(dicVal.keys())[list(dicVal.values()).index(output)])
# Out:
# [7]
# Possible winner : DD

# %%
output
# Out:
# array([2], dtype=int64)

# %%
team1='KXIP'
team2='RCB'
toss_winner='RCB'
input=[dicVal[team1],dicVal[team2],'6',dicVal[toss_winner],'12','9']
input = np.array(input).reshape((1, -1))
output=model.predict(input)
print(output)
print("Possible winner : "+list(dicVal.keys())[list(dicVal.values()).index(output)])
#predictor_var = ['team1', 'team2', 'venue', 'toss_winner','city','toss_decision']
# Out:
# [3]
# Possible winner : RCB

# %%
df
# Out:
#      team1  team2  city  toss_decision  toss_winner  venue  winner
# 0        3      4    23              0            4      4       3
# 1        7      2    10              0            7      8       7
# 2        1      2    23              1            1     35       1
# 3       11      3    26              1           11     17       3
# 4        5      4    23              0            5      4       5
# ..     ...    ...   ...            ...          ...    ...     ...
# 741     10      1    15              1           10     24      10
# 742      5      4    14              0            5      2       5
# 743      3      1     2              1            1     14       1
# 744      9      3    12              1            9      6       9
# 745      3      1     2              1            3     14       1
#
# [746 rows x 7 columns]

# %%
team1='SRH'
team2='MI'
toss_winner='SRH'
input=[dicVal[team1],dicVal[team2],'24',dicVal[toss_winner],'15','1']
input = np.array(input).reshape((1, -1))
output=model.predict(input)
print(output)
print("Possible winner : "+list(dicVal.keys())[list(dicVal.values()).index(output)])
#predictor_var = ['team1', 'team2', 'venue', 'toss_winner','city','toss_decision']
# Out:
# [10]
# Possible winner : SRH

# %%
dicVal
# Out:
# {'MI': 1,
#  'KKR': 2,
#  'RCB': 3,
#  'DC': 4,
#  'CSK': 5,
#  'RR': 6,
#  'DD': 7,
#  'GL': 8,
#  'KXIP': 9,
#  'SRH': 10,
#  'RPS': 11,
#  'KTK': 12,
#  'PW': 13,
#  'Draw': 14}

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
outcome_var = ['winner']
predictor_var = ['team1', 'team2', 'venue', 'toss_winner','city','toss_decision']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Training Model Accuracy 86.99731903485255
# Testing Model Accuracy 96.79144385026738

# %%
team1='SRH'
team2='MI'
toss_winner='MI'
input=[dicVal[team1],dicVal[team2],'24',dicVal[toss_winner],'15','1']
input = np.array(input).reshape((1, -1))
output=model.predict(input)
print(output)
print("Possible winner : "+list(dicVal.keys())[list(dicVal.values()).index(output)])
#predictor_var = ['team1', 'team2', 'venue', 'toss_winner','city','toss_decision']
# Out:
# [10]
# Possible winner : SRH
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\utils\validation.py:532: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
# C:\Users\paras\Anaconda3\lib\site-packages\sklearn\utils\validation.py:532: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
